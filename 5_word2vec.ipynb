# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3082, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.063261
# Nearest to his: deadpan, cosmography, enjoyed, birthrate, richmond, tyrant, pineal, photographers,
# Nearest to up: regency, jaspers, ice, grits, mpaa, mitzvah, congruence, norte,
# Nearest to six: simulate, explosions, sms, cardinal, transcending, grizzly, mea, endowment,
# Nearest to war: catalytic, tire, transformations, unfashionable, licht, seizure, governs, cloth,
# Nearest to two: beet, fab, observables, limb, heralded, egg, capitan, gandhara,
# Nearest to also: blues, issued, steadily, distilling, puebla, guelfs, scythian, nafta,
# Nearest to used: dining, pangloss, lunch, sala, abate, caesars, rightly, eurofighter,
# Nearest to people: himalayan, harassing, balaton, historian, ainsworth, timber, avignon, donations,
# Nearest to system: repeater, nye, isometric, publication, overcame, characterize, mersey, prosecutions,
# Nearest to it: mitosis, goitre, rod, craft, measurable, rapping, darwinism, mundar,
# Nearest to zero: joke, urey, dante, playoff, littlefield, toothed, standardize, tynwald,
# Nearest to years: anacreon, macroeconomic, ghq, scattering, complaining, versus, dane, chu,
# Nearest to may: mines, troyes, isa, spoofing, sensed, unrestrained, dolmen, inning,
# Nearest to as: herero, vlaamse, apple, billy, leander, unlucky, loo, paper,
# Nearest to time: paulus, forbidding, cheney, comprehension, chs, missouri, musician, sparked,
# Nearest to four: platforms, taraza, partitive, balzac, wealthier, symbology, gatling, pollack,
# Average loss at step 2000: 4.374024
# Average loss at step 4000: 3.868508
# Average loss at step 6000: 3.789100
# Average loss at step 8000: 3.686059
# Average loss at step 10000: 3.618098
# Nearest to his: their, the, its, her, s, cornered, loathing, rhythmically,
# Nearest to up: putty, nernst, jew, naguib, shoe, ice, replay, jaspers,
# Nearest to six: eight, seven, four, five, three, nine, zero, two,
# Nearest to war: catalytic, licht, tire, save, seizure, governs, unfashionable, excerpt,
# Nearest to two: three, four, five, six, eight, seven, nine, zero,
# Nearest to also: millikan, who, adventurers, which, lodges, charlestown, skyscraper, tamazight,
# Nearest to used: abate, alkaline, considered, curly, located, sala, instrumentals, pangloss,
# Nearest to people: harassing, himalayan, balaton, betrayal, naturalization, sutras, oprah, solve,
# Nearest to system: isometric, mersey, nye, overcame, characterize, fatale, speaker, unclear,
# Nearest to it: he, this, they, mitosis, that, there, which, not,
# Nearest to zero: eight, five, nine, seven, six, three, four, two,
# Nearest to years: anacreon, macroeconomic, ghq, chu, versus, rien, complaining, lagrangian,
# Nearest to may: mines, transonic, troyes, tacitus, can, shown, covalently, digger,
# Nearest to as: mention, progenitors, billy, unlucky, ischemic, by, cellar, became,
# Nearest to time: comprehension, chs, missouri, columbanus, cathari, forbidding, silvia, vanishing,
# Nearest to four: eight, six, three, five, seven, two, nine, zero,
# Average loss at step 12000: 3.603596
# Average loss at step 14000: 3.571922
# Average loss at step 16000: 3.408722
# Average loss at step 18000: 3.456633
# Average loss at step 20000: 3.539098
# Nearest to his: their, her, its, the, vive, storybook, scope, crystal,
# Nearest to up: back, nernst, jew, putty, patrick, bargaining, ice, meet,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to war: catalytic, licht, tire, dignitaries, save, inflection, seizure, maaouya,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to also: millikan, who, which, generally, not, still, there, often,
# Nearest to used: abate, considered, defined, located, alkaline, islami, enamoured, asked,
# Nearest to people: himalayan, harassing, sutras, optimates, cliches, children, crews, vibration,
# Nearest to system: mersey, metaphor, isometric, fatale, needy, unclear, overcame, mpd,
# Nearest to it: he, this, there, they, which, not, she, alarc,
# Nearest to zero: five, six, eight, seven, nine, three, four, two,
# Nearest to years: ghq, versus, macroeconomic, lagrangian, complaining, conurbation, anacreon, rien,
# Nearest to may: can, would, must, will, could, should, transonic, tacitus,
# Nearest to as: nmi, patrice, dimensional, observance, billy, ischemic, mention, digitized,
# Nearest to time: chs, comprehension, vanishing, missouri, cathari, columbanus, forbidding, joshi,
# Nearest to four: three, six, seven, eight, five, two, nine, one,
# Average loss at step 22000: 3.504433
# Average loss at step 24000: 3.492699
# Average loss at step 26000: 3.480845
# Average loss at step 28000: 3.483651
# Average loss at step 30000: 3.505752
# Nearest to his: their, her, its, the, s, fini, fudge, prattica,
# Nearest to up: back, nernst, jew, buttstock, putty, him, out, jaspers,
# Nearest to six: four, eight, seven, nine, five, three, two, zero,
# Nearest to war: catalytic, tire, excerpt, save, licht, kay, sentiment, inflection,
# Nearest to two: four, three, one, five, seven, six, eight, zero,
# Nearest to also: still, which, who, millikan, generally, actually, sometimes, often,
# Nearest to used: known, considered, abate, defined, alkaline, written, found, located,
# Nearest to people: himalayan, children, wargame, others, harassing, sutras, optimates, arminian,
# Nearest to system: speaker, metaphor, mersey, using, homeomorphic, mk, needy, systems,
# Nearest to it: he, there, this, they, she, which, who, said,
# Nearest to zero: five, eight, seven, four, three, six, nine, two,
# Nearest to years: ghq, versus, conurbation, lagrangian, rien, complaining, chu, hector,
# Nearest to may: can, would, must, will, should, could, to, transonic,
# Nearest to as: patrice, became, ischemic, billy, cortical, simpler, nmi, inapplicable,
# Nearest to time: chs, day, martian, period, place, lemon, comprehension, up,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Average loss at step 32000: 3.501598
# Average loss at step 34000: 3.496111
# Average loss at step 36000: 3.454522
# Average loss at step 38000: 3.301390
# Average loss at step 40000: 3.430128
# Nearest to his: her, their, its, the, s, your, carbides, aileen,
# Nearest to up: back, out, them, jew, nernst, him, buttstock, seizure,
# Nearest to six: four, seven, five, eight, three, nine, two, one,
# Nearest to war: catalytic, licht, sentiment, save, arcas, dignitaries, kay, decoction,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Nearest to also: still, which, generally, often, usually, who, actually, sometimes,
# Nearest to used: found, considered, written, known, defined, located, done, rhymes,
# Nearest to people: wargame, others, children, men, teams, himalayan, americans, jews,
# Nearest to system: systems, speaker, metaphor, homeomorphic, mersey, definition, mk, tourism,
# Nearest to it: he, there, she, they, this, which, but, not,
# Nearest to zero: seven, five, eight, nine, six, three, two, four,
# Nearest to years: days, months, ghq, versus, locks, hector, minutes, rien,
# Nearest to may: can, will, would, must, could, should, cannot, might,
# Nearest to as: nmi, when, billy, mar, variably, is, inapplicable, png,
# Nearest to time: chs, day, joshi, boerhaave, lemon, way, place, period,
# Nearest to four: six, eight, seven, five, three, two, nine, one,
# Average loss at step 42000: 3.436250
# Average loss at step 44000: 3.451897
# Average loss at step 46000: 3.449420
# Average loss at step 48000: 3.348278
# Average loss at step 50000: 3.386360
# Nearest to his: her, their, its, the, my, your, aileen, fini,
# Nearest to up: out, them, back, off, jew, him, buttstock, nernst,
# Nearest to six: seven, eight, four, five, three, nine, two, zero,
# Nearest to war: licht, catalytic, dignitaries, sentiment, ghiorso, kay, pics, rsc,
# Nearest to two: three, four, one, six, seven, five, eight, zero,
# Nearest to also: which, still, often, generally, who, actually, sometimes, now,
# Nearest to used: written, known, considered, defined, found, referred, able, designed,
# Nearest to people: men, children, jews, wrought, others, teams, wargame, words,
# Nearest to system: systems, metaphor, speaker, meps, homeomorphic, worldstatesmen, audio, definition,
# Nearest to it: he, there, she, this, they, now, fermion, still,
# Nearest to zero: seven, five, four, eight, six, three, nine, two,
# Nearest to years: days, months, year, decades, locks, minutes, ghq, libyans,
# Nearest to may: can, would, must, will, could, should, might, cannot,
# Nearest to as: billy, became, ischemic, inapplicable, variably, nmi, unlucky, cortical,
# Nearest to time: chs, day, way, period, victory, year, cryptozoologists, place,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Average loss at step 52000: 3.436322
# Average loss at step 54000: 3.426634
# Average loss at step 56000: 3.441192
# Average loss at step 58000: 3.398987
# Average loss at step 60000: 3.396541
# Nearest to his: her, their, its, my, sega, your, the, aileen,
# Nearest to up: out, them, off, back, him, jew, seizure, down,
# Nearest to six: four, five, eight, seven, nine, three, two, zero,
# Nearest to war: licht, dignitaries, germanium, ghiorso, sentiment, catalytic, reprinted, kay,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to also: still, now, often, sometimes, generally, actually, who, which,
# Nearest to used: written, found, known, defined, designed, considered, seen, described,
# Nearest to people: men, jews, others, children, americans, scholars, members, those,
# Nearest to system: systems, metaphor, mortgages, homeomorphic, definition, meps, mersey, worldstatesmen,
# Nearest to it: he, there, she, this, they, still, which, unclear,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to years: days, months, decades, weeks, year, minutes, hours, libyans,
# Nearest to may: can, would, will, must, should, could, might, cannot,
# Nearest to as: locally, nmi, ischemic, unlucky, ideologically, kilby, cortical, rarely,
# Nearest to time: victory, period, way, chs, segr, day, kind, motive,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Average loss at step 62000: 3.240580
# Average loss at step 64000: 3.256360
# Average loss at step 66000: 3.401578
# Average loss at step 68000: 3.392483
# Average loss at step 70000: 3.360162
# Nearest to his: her, their, its, my, your, the, him, fini,
# Nearest to up: out, off, them, back, him, down, intermarriages, seizure,
# Nearest to six: eight, four, five, seven, nine, three, zero, two,
# Nearest to war: licht, ghiorso, germanium, cia, catalytic, kay, reprinted, dignitaries,
# Nearest to two: three, six, four, five, seven, one, eight, zero,
# Nearest to also: still, now, often, generally, which, sometimes, actually, usually,
# Nearest to used: written, known, designed, found, seen, defined, responsible, considered,
# Nearest to people: men, jews, children, others, someone, americans, members, chi,
# Nearest to system: systems, borrowing, metaphor, mortgages, homeomorphic, compliment, tourism, ingolstadt,
# Nearest to it: he, she, there, this, they, still, god, glued,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to years: days, months, decades, weeks, minutes, year, hours, centuries,
# Nearest to may: can, would, will, must, should, could, might, cannot,
# Nearest to as: before, unlucky, mar, digitized, billy, cortical, wally, suction,
# Nearest to time: chs, way, victory, jurisprudence, manner, segr, motive, bureaucrat,
# Nearest to four: six, five, three, seven, eight, zero, nine, two,
# Average loss at step 72000: 3.370641
# Average loss at step 74000: 3.349499
# Average loss at step 76000: 3.318877
# Average loss at step 78000: 3.360381
# Average loss at step 80000: 3.380269
# Nearest to his: her, their, its, your, my, our, the, him,
# Nearest to up: out, off, them, back, him, down, shaving, seizure,
# Nearest to six: five, four, eight, seven, three, nine, two, zero,
# Nearest to war: ghiorso, sentiment, germanium, licht, mazar, catalytic, dignitaries, larsen,
# Nearest to two: four, three, six, five, seven, one, eight, zero,
# Nearest to also: still, now, often, sometimes, which, actually, commonly, generally,
# Nearest to used: written, known, designed, found, seen, defined, responsible, referred,
# Nearest to people: men, children, jews, someone, words, others, americans, wargame,
# Nearest to system: systems, mortgages, borrowing, compliment, amerindians, metaphor, worldstatesmen, homeomorphic,
# Nearest to it: he, there, she, this, we, they, not, never,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to years: days, months, minutes, weeks, decades, year, hours, centuries,
# Nearest to may: can, will, would, must, could, should, might, cannot,
# Nearest to as: mar, fernand, cortical, when, nmi, variably, ischemic, before,
# Nearest to time: victory, year, segr, period, mikvah, situation, chs, day,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Average loss at step 82000: 3.407083
# Average loss at step 84000: 3.412824
# Average loss at step 86000: 3.391121
# Average loss at step 88000: 3.353173
# Average loss at step 90000: 3.367281
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to up: off, out, back, them, him, down, unavoidable, buttstock,
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to war: wars, factbook, reprinted, fumes, cia, colony, sherbrooke, licht,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to also: now, still, often, which, sometimes, actually, never, generally,
# Nearest to used: designed, known, written, found, seen, referred, defined, responsible,
# Nearest to people: men, children, jews, someone, americans, women, members, peoples,
# Nearest to system: systems, homeomorphic, metaphor, mortgages, worldstatesmen, device, edith, compliment,
# Nearest to it: he, she, there, this, they, which, never, not,
# Nearest to zero: five, seven, six, eight, nine, four, three, two,
# Nearest to years: days, months, minutes, weeks, decades, hours, year, centuries,
# Nearest to may: can, must, should, could, will, might, would, cannot,
# Nearest to as: mar, cortical, fernand, variably, nmi, locally, digitized, lascaris,
# Nearest to time: period, segr, manner, victory, appointing, way, chs, day,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Average loss at step 92000: 3.397269
# Average loss at step 94000: 3.254806
# Average loss at step 96000: 3.358653
# Average loss at step 98000: 3.247767
# Average loss at step 100000: 3.353353
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to up: off, out, back, them, him, down, unavoidable, seizure,
# Nearest to six: seven, four, five, eight, nine, three, two, zero,
# Nearest to war: factbook, wars, reprinted, colony, sentiment, imminent, fumes, cia,
# Nearest to two: four, five, three, six, one, seven, eight, zero,
# Nearest to also: now, still, actually, sometimes, often, generally, never, usually,
# Nearest to used: designed, written, found, responsible, known, defined, referred, applied,
# Nearest to people: children, men, jews, someone, peoples, women, individuals, americans,
# Nearest to system: systems, metaphor, homeomorphic, worldstatesmen, compliment, process, device, model,
# Nearest to it: he, she, this, there, they, never, unclear, fermion,
# Nearest to zero: five, four, seven, eight, six, nine, two, three,
# Nearest to years: days, months, decades, minutes, weeks, year, hours, centuries,
# Nearest to may: can, must, could, should, might, will, would, cannot,
# Nearest to as: cortical, mar, when, variably, like, pratyeka, inconsistency, digitized,
# Nearest to time: period, victory, chs, year, manner, kind, way, season,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
#skip_window = 1 # How many words to consider left and right.
#num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.734587
# Nearest to one: lv, mev, hercules, montreal, buccaneers, floresiensis, astronomically, flavian,
# Nearest to after: fawn, liqueurs, interpreting, pasolini, kryptonite, cosmonauts, limitation, wavefunction,
# Nearest to were: cameroons, freeza, underlying, marshallese, shedding, amnesia, karzai, squeeze,
# Nearest to from: fixed, cleanse, opcode, orchid, macrobiotics, overall, min, auditum,
# Nearest to up: hooks, submits, separating, ue, provided, divide, ticonderoga, isolate,
# Nearest to between: tron, pitchers, withhold, mithraea, antibody, peshawar, once, cite,
# Nearest to no: buchan, bacon, frameworks, injection, phagspa, shit, charitable, fossils,
# Nearest to he: munster, himalayan, tipton, afewerki, avignon, tarsus, appendage, profil,
# Nearest to time: evacuate, sabbath, potencies, ailes, aman, disinterested, kobe, adversary,
# Nearest to world: aberration, fredrik, bulletin, beers, implanted, supersymmetry, ins, caricature,
# Nearest to two: skyview, cloudbusting, studs, advancements, dennis, hires, backtracking, werner,
# Nearest to most: neocortex, gila, longwave, aida, faroes, zhou, pvp, paralleled,
# Nearest to have: patent, jericho, arexx, gda, terrifying, pelvis, mycoplasma, nm,
# Nearest to history: scout, parson, marlowe, drunken, piqad, cleaning, consequentialism, greenman,
# Nearest to if: eloquent, epiphanius, diazepam, abelian, divergences, mini, diluted, antidepressant,
# Nearest to b: vyasa, speaker, provocation, announces, distortions, catal, rq, ghanima,
# Average loss at step 2000: 4.617740
# Average loss at step 4000: 3.956013
# Average loss at step 6000: 3.727799
# Average loss at step 8000: 3.542167
# Average loss at step 10000: 3.476871
# Nearest to one: two, faisal, pectoral, zero, calibers, nilotic, terrorist, theism,
# Nearest to after: before, yap, oriental, seleucus, yn, cerebellum, schedules, uighur,
# Nearest to were: are, was, had, zoroastrianism, cartography, mand, ljubljana, is,
# Nearest to from: micah, at, lasts, through, mic, herding, into, intrigues,
# Nearest to up: hooks, basins, lifted, isolate, untrue, lillard, catalog, submits,
# Nearest to between: harnessing, buttocks, humanoids, array, gibb, videotaped, hospitalized, albigensian,
# Nearest to no: each, bulges, hp, christus, stupidity, essays, another, undermines,
# Nearest to he: she, it, they, who, max, wordsworth, mucus, rake,
# Nearest to time: enterprises, willys, least, busey, nirvana, keeps, zs, jonah,
# Nearest to world: riot, antipsychotic, caricature, mok, curve, proclamation, leonard, uploaded,
# Nearest to two: three, seven, zero, four, eight, six, five, nine,
# Nearest to most: many, some, more, extremes, martov, adoption, offerings, introspection,
# Nearest to have: had, has, ky, having, sanders, keepers, be, fun,
# Nearest to history: ballast, batch, arminians, selma, routers, baptise, guthrie, ornithology,
# Nearest to if: cassava, when, qquad, jagiellonian, ordeal, abelian, unlikely, diazepam,
# Nearest to b: d, princesses, censure, kampaku, frontal, medications, hervey, cycled,
# Average loss at step 12000: 3.475007
# Average loss at step 14000: 3.445900
# Average loss at step 16000: 3.438042
# Average loss at step 18000: 3.402390
# Average loss at step 20000: 3.213795
# Nearest to one: probing, bronchitis, two, hexadecimal, banting, ezekiel, catwoman, robustness,
# Nearest to after: before, during, homepage, through, when, oriental, while, wakefulness,
# Nearest to were: are, was, is, have, ljubljana, dickinson, conversations, be,
# Nearest to from: through, herding, micah, including, since, bbn, lending, into,
# Nearest to up: out, casale, basins, methanol, catalog, rim, him, hooks,
# Nearest to between: into, with, harnessing, encircle, in, buttocks, dictator, mutually,
# Nearest to no: tov, little, hp, been, bulges, become, injection, grained,
# Nearest to he: she, it, they, who, caxton, options, reliance, articulations,
# Nearest to time: end, period, least, willys, emanate, same, jonah, busey,
# Nearest to world: guilds, antipsychotic, leather, ligase, practice, tigrinya, ascertain, homily,
# Nearest to two: three, seven, nine, four, eight, six, five, zero,
# Nearest to most: many, more, some, very, bough, among, melchior, marlene,
# Nearest to have: had, has, are, having, be, include, were, ky,
# Nearest to history: list, subdivision, dao, maximinus, pipes, routers, ancient, yusupov,
# Nearest to if: when, where, because, cassava, must, though, qquad, linkin,
# Nearest to b: d, recluse, warwick, loosened, seven, dietrich, h, nasdaq,
# Average loss at step 22000: 3.362563
# Average loss at step 24000: 3.293070
# Average loss at step 26000: 3.263247
# Average loss at step 28000: 3.285685
# Average loss at step 30000: 3.221862
# Nearest to one: two, banting, jing, taxpayers, pharmacies, sas, sturgeon, guilford,
# Nearest to after: before, during, through, for, despite, while, schedules, since,
# Nearest to were: are, was, include, have, is, boating, mounts, stimuli,
# Nearest to from: through, into, including, back, fung, micah, by, under,
# Nearest to up: out, basins, them, endless, gallico, down, collective, shielded,
# Nearest to between: with, harnessing, mutually, into, buttocks, among, medal, orphan,
# Nearest to no: any, little, hp, each, trombones, charitable, pollute, tov,
# Nearest to he: she, it, they, be, hesychastic, kilmister, tribunals, moxie,
# Nearest to time: end, period, least, year, planina, resurgence, alliterative, busey,
# Nearest to world: immunodeficiency, eolian, homily, originality, antipsychotic, caricature, inhibitory, spectrum,
# Nearest to two: six, three, eight, four, one, zero, nine, five,
# Nearest to most: many, some, more, less, best, disguise, very, apostasy,
# Nearest to have: has, had, having, produce, include, ky, are, contain,
# Nearest to history: list, samples, maps, version, apathy, influence, abdur, department,
# Nearest to if: though, when, where, because, since, however, corpuscles, before,
# Nearest to b: f, h, p, reiterated, melancholic, r, bandar, mathrm,
# Average loss at step 32000: 3.013111
# Average loss at step 34000: 3.205251
# Average loss at step 36000: 3.193117
# Average loss at step 38000: 3.161375
# Average loss at step 40000: 3.163331
# Nearest to one: two, six, three, cet, adorning, hexadecimal, banting, guilford,
# Nearest to after: before, during, since, in, despite, while, through, for,
# Nearest to were: are, was, is, had, include, became, being, devolved,
# Nearest to from: through, micah, into, back, herding, including, within, maintains,
# Nearest to up: out, off, down, them, gonzalo, guerrilla, back, hint,
# Nearest to between: within, among, harnessing, into, with, excellency, in, mutually,
# Nearest to no: little, any, hp, jigs, tov, an, menthol, injection,
# Nearest to he: she, it, they, maule, caxton, piping, ashes, losers,
# Nearest to time: least, end, beginning, period, resurgence, times, point, willys,
# Nearest to world: independence, memel, homily, bitches, inhibitory, eldr, second, bitmap,
# Nearest to two: five, six, three, four, zero, seven, eight, nine,
# Nearest to most: less, more, some, offerings, many, best, very, because,
# Nearest to have: has, had, contain, having, produce, include, ky, be,
# Nearest to history: abdur, limburgish, petrol, evade, schmidt, sforza, volume, timeline,
# Nearest to if: though, when, where, since, although, because, until, stemmed,
# Nearest to b: d, c, por, hostel, reiterated, altruism, p, h,
# Average loss at step 42000: 3.215552
# Average loss at step 44000: 3.141955
# Average loss at step 46000: 3.141493
# Average loss at step 48000: 3.056830
# Average loss at step 50000: 3.058704
# Nearest to one: two, sprint, dat, trouv, dragged, gadol, affective, chesterfield,
# Nearest to after: before, during, when, through, smoother, without, following, afterwards,
# Nearest to were: are, was, is, being, include, had, exist, remained,
# Nearest to from: through, into, disordered, across, during, before, when, in,
# Nearest to up: off, out, together, xb, down, him, untrue, casale,
# Nearest to between: with, within, mutually, collegiate, over, humanoids, bangkok, excellency,
# Nearest to no: any, little, nothing, some, braintree, wrongdoing, gaiman, a,
# Nearest to he: she, it, they, who, erosive, hesychastic, kilmister, bruford,
# Nearest to time: period, point, least, times, resurgence, year, willys, telescope,
# Nearest to world: inhibitory, ligase, eldr, mok, basingstoke, homily, statistician, gst,
# Nearest to two: four, five, three, six, seven, eight, one, zero,
# Nearest to most: more, many, less, especially, particularly, all, earliest, best,
# Nearest to have: has, had, having, contain, produce, require, include, mean,
# Nearest to history: list, timeline, atlas, theorems, schmidt, museum, supplier, limburgish,
# Nearest to if: when, where, though, although, because, while, since, proselytes,
# Nearest to b: d, te, frankfort, jaffe, comedians, hindrance, nobel, censure,
# Average loss at step 52000: 3.100943
# Average loss at step 54000: 3.096224
# Average loss at step 56000: 2.929202
# Average loss at step 58000: 3.027085
# Average loss at step 60000: 3.051975
# Nearest to one: hexadecimal, two, metafont, tallies, aragorn, faisal, vortigern, topless,
# Nearest to after: before, during, following, through, when, since, afterwards, without,
# Nearest to were: are, was, is, include, remained, had, being, tasting,
# Nearest to from: into, through, back, under, herding, northward, micah, beyond,
# Nearest to up: off, out, down, quantifiers, pass, basins, back, casale,
# Nearest to between: with, over, among, within, ogilvie, buttocks, harnessing, collegiate,
# Nearest to no: little, another, nothing, a, any, become, every, considerable,
# Nearest to he: she, it, they, who, mucus, kilmister, already, smith,
# Nearest to time: period, point, telescope, victory, year, least, willys, end,
# Nearest to world: memel, statistician, gst, drab, mok, europe, darkly, basingstoke,
# Nearest to two: three, four, five, six, zero, eight, several, nine,
# Nearest to most: many, some, more, especially, particularly, all, best, offerings,
# Nearest to have: had, has, having, contain, produce, create, include, be,
# Nearest to history: list, society, reign, version, abdur, concept, routers, journal,
# Nearest to if: when, though, although, where, because, fuelling, should, before,
# Nearest to b: d, c, ki, outfielders, incompletely, condoleezza, v, h,
# Average loss at step 62000: 3.017755
# Average loss at step 64000: 2.920704
# Average loss at step 66000: 2.941227
# Average loss at step 68000: 2.959611
# Average loss at step 70000: 3.011662
# Nearest to one: two, compactification, las, floresiensis, gw, loc, taya, pectoral,
# Nearest to after: before, during, following, for, when, despite, throughout, without,
# Nearest to were: are, was, is, had, ljubljana, include, being, remained,
# Nearest to from: through, into, bbn, since, beyond, kristofferson, across, back,
# Nearest to up: off, together, out, down, back, uncertainty, extraordinary, pms,
# Nearest to between: among, within, with, venona, orphan, into, over, thus,
# Nearest to no: nothing, kinky, little, another, become, lemmings, uga, braintree,
# Nearest to he: she, it, they, who, articulations, hesychastic, erosive, amused,
# Nearest to time: least, period, victory, beginning, point, end, start, procopius,
# Nearest to world: vietnam, con, solicitors, gst, memel, attendance, concisely, summer,
# Nearest to two: three, five, six, zero, seven, eight, four, nine,
# Nearest to most: many, more, particularly, pickled, some, highly, earliest, especially,
# Nearest to have: had, has, contain, include, produce, having, require, reach,
# Nearest to history: origin, list, coronation, version, evolution, study, concept, victories,
# Nearest to if: when, though, fuelling, where, although, unless, since, liberally,
# Nearest to b: d, improvisations, brews, manson, philosopher, condoleezza, astm, downgraded,
# Average loss at step 72000: 2.938811
# Average loss at step 74000: 2.869611
# Average loss at step 76000: 2.991842
# Average loss at step 78000: 3.006273
# Average loss at step 80000: 2.849014
# Nearest to one: utf, pectoral, faisal, microfilm, wolverine, debrecen, tachyon, aragorn,
# Nearest to after: before, during, afterwards, following, within, despite, while, thereafter,
# Nearest to were: are, was, is, include, ljubljana, chagos, remained, boating,
# Nearest to from: through, including, into, within, sven, micah, across, back,
# Nearest to up: together, down, out, off, back, gonzalo, xb, atrium,
# Nearest to between: with, among, within, ogilvie, therefore, nicomedia, dram, buttocks,
# Nearest to no: little, nothing, any, braintree, considerable, only, blotting, trombones,
# Nearest to he: she, it, they, caxton, hesychastic, killian, ecclesiastica, unshielded,
# Nearest to time: period, beginning, moment, least, foothold, victory, night, end,
# Nearest to world: homily, country, opium, statistician, drab, neoconservatism, memel, euphonium,
# Nearest to two: three, four, nine, five, six, zero, expellees, eight,
# Nearest to most: many, more, particularly, some, less, pickled, greatest, first,
# Nearest to have: had, has, having, contain, create, be, produce, provide,
# Nearest to history: map, biography, list, demographics, study, geography, series, mainstream,
# Nearest to if: though, when, before, although, where, therefore, because, unless,
# Nearest to b: d, frick, misspelling, improvisations, brews, coen, stromata, astm,
# Average loss at step 82000: 2.931875
# Average loss at step 84000: 2.901553
# Average loss at step 86000: 2.920959
# Average loss at step 88000: 2.945622
# Average loss at step 90000: 2.828267
# Nearest to one: seven, two, four, idi, faisal, innings, roamed, six,
# Nearest to after: before, during, afterwards, within, without, following, thereafter, when,
# Nearest to were: are, was, banded, is, had, boating, include, produce,
# Nearest to from: into, after, including, in, micah, during, via, through,
# Nearest to up: off, out, back, down, together, sailplane, easier, reference,
# Nearest to between: with, ogilvie, among, within, buttocks, against, across, thus,
# Nearest to no: nothing, little, any, braintree, prospects, suburban, another, scottie,
# Nearest to he: she, it, they, hesychastic, ecclesiastica, hitler, specify, unscathed,
# Nearest to time: period, least, moment, height, request, beginning, planina, victory,
# Nearest to world: homily, country, accords, opium, epigrams, summer, con, buttstock,
# Nearest to two: three, four, six, five, nine, triumphs, one, zero,
# Nearest to most: many, particularly, some, less, especially, both, more, highly,
# Nearest to have: has, had, contain, produce, having, include, require, create,
# Nearest to history: list, geography, map, version, study, religion, biography, embassy,
# Nearest to if: though, when, where, therefore, although, unless, lonely, whether,
# Nearest to b: cygwin, garrett, scarlet, uniquely, accomplishes, asturias, laypeople, unmarried,
# Average loss at step 92000: 2.897768
# Average loss at step 94000: 2.883583
# Average loss at step 96000: 2.713052
# Average loss at step 98000: 2.463894
# Average loss at step 100000: 2.709562
# Nearest to one: innings, comm, pectoral, conakry, topless, vouchers, las, idi,
# Nearest to after: before, following, afterwards, without, within, through, despite, for,
# Nearest to were: are, was, is, have, had, devolved, chagos, being,
# Nearest to from: across, into, bbn, via, by, beyond, maintains, micah,
# Nearest to up: off, out, down, together, back, hainan, dail, starved,
# Nearest to between: among, thus, with, across, in, ogilvie, within, around,
# Nearest to no: any, little, nothing, blotting, braintree, another, contravention, leutze,
# Nearest to he: she, it, they, hesychastic, caxton, ecclesiastica, schumacher, smith,
# Nearest to time: period, moment, height, least, night, point, request, times,
# Nearest to world: summer, con, opium, mok, trojan, jump, inception, vietnam,
# Nearest to two: three, five, seven, four, six, eight, nine, zero,
# Nearest to most: particularly, more, some, quite, best, especially, less, many,
# Nearest to have: had, has, contain, having, produce, include, require, are,
# Nearest to history: list, era, culture, vancouver, encyclopedia, literature, origin, society,
# Nearest to if: when, though, where, because, unless, therefore, although, while,
# Nearest to b: d, improvisations, slr, idleness, goaltender, router, rutles, donating,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
